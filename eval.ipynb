# %%
import os
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import StratifiedGroupKFold, train_test_split

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import tensorflow as tf
#       7 from tensorflow import keras
# ----> 8 from sklearn.model_selection import StratifiedGroupKFold, train_test_split
#      10 from sklearn.utils.class_weight import compute_class_weight
#      11 from sklearn.metrics import (
#      12     classification_report, confusion_matrix, ConfusionMatrixDisplay
#      13 )
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model('model/output/driving_cnn.keras')

# %%
test_loss, test_accuracy = loaded_model.evaluate(X_test, y_test, verbose=1)

# Print the results
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
